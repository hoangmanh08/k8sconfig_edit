# %%
import toml
import pandas as pd

# Hàm đệ quy để tạo các key dạng chuỗi theo định dạng cần thiết
def flatten_toml(d, parent_key='', sep='.'):
    items = []
    for k, v in d.items():
        new_key = f"{parent_key}{sep}{k}" if parent_key else k
        if isinstance(v, dict):
            items.extend(flatten_toml(v, new_key, sep=sep).items())
        elif isinstance(v, list):
            for idx, item in enumerate(v):
                items.append((f"{new_key}[{idx}]", item))
        else:
            items.append((new_key, v))
    return dict(items)

# Đọc file TOML
def toml_to_excel(toml_file, excel_file):
    with open(toml_file, 'r') as f:
        toml_data = toml.load(f)
    
    # Phẳng hóa dữ liệu TOML
    flattened_data = flatten_toml(toml_data)
    
    # Chuyển thành DataFrame
    df = pd.DataFrame(list(flattened_data.items()), columns=['Key', 'Value'])
    
    # Lưu DataFrame thành file Excel
    df.to_excel(excel_file, index=False)

# Đọc file TOML và chuyển đổi thành file Excel
toml_file = '/workspaces/k8sconfig_edit/tom_edit/config.toml'  # Đặt tên file TOML của bạn
excel_file = 'output11111111.xlsx'  # Đặt tên file Excel bạn muốn xuất ra
toml_to_excel(toml_file, excel_file)

print(f"Đã chuyển đổi thành công từ TOML sang Excel. Xem kết quả tại {excel_file}")
# Out:
# Đã chuyển đổi thành công từ TOML sang Excel. Xem kết quả tại output11111111.xlsx

# %%
import toml
import pandas as pd

# Hàm đệ quy để tạo các key dạng chuỗi theo định dạng cần thiết
def flatten_toml(d, parent_key='', sep='.'):
    items = []
    for k, v in d.items():
        new_key = f"{parent_key}{sep}{k}" if parent_key else k
        if isinstance(v, dict):
            items.extend(flatten_toml(v, new_key, sep=sep).items())
        elif isinstance(v, list):
            if len(v) == 0:  # Nếu là danh sách trống, giữ lại []
                items.append((new_key, '[]'))
            else:
                for idx, item in enumerate(v):
                    items.append((f"{new_key}[{idx}]", item))
        else:
            if v == "":  # Nếu là chuỗi rỗng, giữ lại ""
                items.append((new_key, ''))
            else:
                items.append((new_key, v))
    return dict(items)

# Đọc file TOML
def toml_to_excel(toml_file, excel_file):
    with open(toml_file, 'r') as f:
        toml_data = toml.load(f)
    
    # Phẳng hóa dữ liệu TOML
    flattened_data = flatten_toml(toml_data)
    
    # Chuyển thành DataFrame
    df = pd.DataFrame(list(flattened_data.items()), columns=['Key', 'Value'])
    
    # Lưu DataFrame thành file Excel
    df.to_excel(excel_file, index=False)

# Đọc file TOML và chuyển đổi thành file Excel
toml_file = '/workspaces/k8sconfig_edit/tom_edit/config.toml'  # Đặt tên file TOML của bạn
excel_file = 'output222.xlsx'  # Đặt tên file Excel bạn muốn xuất ra
toml_to_excel(toml_file, excel_file)

print(f"Đã chuyển đổi thành công từ TOML sang Excel. Xem kết quả tại {excel_file}")
# Out:
# Đã chuyển đổi thành công từ TOML sang Excel. Xem kết quả tại output222.xlsx

# %%
import toml
import pandas as pd

# Hàm đệ quy để tạo các key dạng chuỗi theo định dạng cần thiết
def flatten_toml(d, parent_key='', sep='.'):
    items = []
    for k, v in d.items():
        new_key = f"{parent_key}{sep}{k}" if parent_key else k
        
        if isinstance(v, dict):
            # Nếu giá trị là dict, tiếp tục đệ quy
            items.extend(flatten_toml(v, new_key, sep=sep).items())
        elif isinstance(v, list):
            if len(v) == 0:  # Nếu là danh sách trống, giữ lại []
                items.append((new_key, '[]'))
            else:
                for idx, item in enumerate(v):
                    # Nếu là list với các dict, xử lý thêm phần index trong key
                    if isinstance(item, dict):
                        items.extend(flatten_toml(item, f"{new_key}[{idx}]", sep=sep).items())
                    else:
                        items.append((f"{new_key}[{idx}]", item))
        else:
            if v == "":  # Nếu là chuỗi rỗng, giữ lại ""
                items.append((new_key, ''))
            else:
                items.append((new_key, v))
    return dict(items)

# Đọc file TOML
def toml_to_excel(toml_file, excel_file):
    with open(toml_file, 'r') as f:
        toml_data = toml.load(f)
    
    # Phẳng hóa dữ liệu TOML
    flattened_data = flatten_toml(toml_data)
    
    # Chuyển thành DataFrame
    df = pd.DataFrame(list(flattened_data.items()), columns=['Key', 'Value'])
    
    # Lưu DataFrame thành file Excel
    df.to_excel(excel_file, index=False)

# Đọc file TOML và chuyển đổi thành file Excel
toml_file = '/workspaces/k8sconfig_edit/tom_edit/config.toml'  # Đặt tên file TOML của bạn
excel_file = 'output333.xlsx'  # Đặt tên file Excel bạn muốn xuất ra
toml_to_excel(toml_file, excel_file)

print(f"Đã chuyển đổi thành công từ TOML sang Excel. Xem kết quả tại {excel_file}")
# Out:
# Đã chuyển đổi thành công từ TOML sang Excel. Xem kết quả tại output333.xlsx

# %%
import toml
import pandas as pd

# Hàm đệ quy để tạo các key dạng chuỗi theo định dạng cần thiết
def flatten_toml(d, parent_key='', sep='.'):
    items = []
    for k, v in d.items():
        new_key = f"{parent_key}{sep}{k}" if parent_key else k
        
        if isinstance(v, dict):
            # Nếu giá trị là dict, tiếp tục đệ quy
            items.extend(flatten_toml(v, new_key, sep=sep).items())
        elif isinstance(v, list):
            if len(v) == 0:  # Nếu là danh sách trống, giữ lại []
                items.append((new_key, '[]'))
            else:
                for idx, item in enumerate(v):
                    # Nếu là list với các dict, xử lý thêm phần index trong key
                    if isinstance(item, dict):
                        items.extend(flatten_toml(item, f"{new_key}[{idx}]", sep=sep).items())
                    else:
                        items.append((f"{new_key}[{idx}]", item))
        else:
            if v == "":  # Nếu là chuỗi rỗng, giữ lại ""
                items.append((new_key, ''))
            else:
                items.append((new_key, v))
    return dict(items)

# Đọc file TOML
def toml_to_excel(toml_file, excel_file):
    with open(toml_file, 'r') as f:
        toml_data = toml.load(f)
    
    # Phẳng hóa dữ liệu TOML
    flattened_data = flatten_toml(toml_data)
    
    # Kiểm tra và thêm các key kết thúc bằng 'auths', 'configs', 'headers', 'mirrors'
    registry_keys_suffixes = ['auths', 'configs', 'headers', 'mirrors']
    
    # Lặp qua tất cả các key trong flattened_data và kiểm tra nếu key kết thúc bằng một trong các suffixes
    for key in list(flattened_data.keys()):
        if any(key.endswith(suffix) for suffix in registry_keys_suffixes) and flattened_data[key] == '':
            flattened_data[key] = ''  # Đảm bảo giữ giá trị chuỗi rỗng cho các key này nếu không có giá trị

    # Chuyển thành DataFrame
    df = pd.DataFrame(list(flattened_data.items()), columns=['Key', 'Value'])
    
    # Lưu DataFrame thành file Excel
    df.to_excel(excel_file, index=False)

# Đọc file TOML và chuyển đổi thành file Excel
toml_file = '/workspaces/k8sconfig_edit/tom_edit/config.toml'  # Đặt tên file TOML của bạn
excel_file = 'output444.xlsx'  # Đặt tên file Excel bạn muốn xuất ra
toml_to_excel(toml_file, excel_file)

print(f"Đã chuyển đổi thành công từ TOML sang Excel. Xem kết quả tại {excel_file}")
# Out:
# Đã chuyển đổi thành công từ TOML sang Excel. Xem kết quả tại output444.xlsx

# %%
import toml
import pandas as pd

# Hàm đệ quy để tạo các key dạng chuỗi theo định dạng cần thiết
def flatten_toml(d, parent_key='', sep='.'):
    items = []
    for k, v in d.items():
        new_key = f"{parent_key}{sep}{k}" if parent_key else k
        
        if isinstance(v, dict):
            # Nếu giá trị là dict, tiếp tục đệ quy
            items.extend(flatten_toml(v, new_key, sep=sep).items())
        elif isinstance(v, list):
            if len(v) == 0:  # Nếu là danh sách trống, giữ lại []
                items.append((new_key, '[]'))
            else:
                for idx, item in enumerate(v):
                    # Nếu là list với các dict, xử lý thêm phần index trong key
                    if isinstance(item, dict):
                        items.extend(flatten_toml(item, f"{new_key}[{idx}]", sep=sep).items())
                    else:
                        items.append((f"{new_key}[{idx}]", item))
        else:
            if v == "":  # Nếu là chuỗi rỗng, giữ lại ""
                items.append((new_key, ''))
            else:
                items.append((new_key, v))
    return dict(items)

# Đọc file TOML
def toml_to_excel(toml_file, excel_file):
    with open(toml_file, 'r') as f:
        toml_data = toml.load(f)
    
    # Phẳng hóa dữ liệu TOML
    flattened_data = flatten_toml(toml_data)
    
    # Lưu các key không có giá trị vào dạng rỗng
    # Đảm bảo rằng các key rỗng (như `auths`, `configs`, v.v.) không bị bỏ qua
    # Lọc ra tất cả các key có dạng `plugins.io.containerd.grpc.v1.cri.registry.*` chưa có giá trị
    registry_keys = [
        "plugins.io.containerd.grpc.v1.cri.registry.auths",
        "plugins.io.containerd.grpc.v1.cri.registry.configs",
        "plugins.io.containerd.grpc.v1.cri.registry.headers",
        "plugins.io.containerd.grpc.v1.cri.registry.mirrors"
    ]
    for key in registry_keys:
        if key not in flattened_data:
            flattened_data[key] = ''

    # Chuyển thành DataFrame
    df = pd.DataFrame(list(flattened_data.items()), columns=['Key', 'Value'])
    
    # Lưu DataFrame thành file Excel
    df.to_excel(excel_file, index=False)

# Đọc file TOML và chuyển đổi thành file Excel
toml_file = '/workspaces/k8sconfig_edit/tom_edit/config.toml'  # Đặt tên file TOML của bạn
excel_file = 'output555.xlsx'  # Đặt tên file Excel bạn muốn xuất ra
toml_to_excel(toml_file, excel_file)

print(f"Đã chuyển đổi thành công từ TOML sang Excel. Xem kết quả tại {excel_file}")
# Out:
# Đã chuyển đổi thành công từ TOML sang Excel. Xem kết quả tại output555.xlsx
